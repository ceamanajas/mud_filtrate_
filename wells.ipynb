# %%
pip install lasio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 kB 613.0 kB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import lasio
import numpy as np
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import missingno as msno

# %%
las = lasio.read('/content/drive/MyDrive/doutorado/mud_filtrate/dados/outros_pocos/660810-B-4H.las')  # lê o arquivo .las
# las = lasio.read('/content/drive/MyDrive/doutorado/mud_filtrate/dados/check-shots-6608_10-2/LOGS_NO_6608_10-2_LAS/NO_6608_10-2.las')
well = las.df().reset_index() # converte para dataframe

# %%
# prompt: transforme em NaN os valores de -9999.0

import numpy as np
well = well.replace(-9999.0, np.nan)

# %%
well = well[10216:13010]
well = well.replace({-9999.0:np.nan, -99.99:np.nan, -4410.4824:np.nan})

# %%
well
# Out:
#           DEPTH        TVD      TVDSS        DT       DTS  GR   KLOGH  NPHI  \
# 10216  2545.125  2521.1287 -2499.1287  103.0394  198.5338 NaN     NaN   NaN
# 10217  2545.250  2521.2537 -2499.2537  102.7770  197.5608 NaN     NaN   NaN
# 10218  2545.375  2521.3787 -2499.3787  102.4858  196.8338 NaN     NaN   NaN
# 10219  2545.500  2521.5037 -2499.5037  102.1904  196.6418 NaN     NaN   NaN
# 10220  2545.625  2521.6287 -2499.6287  101.9438  196.7666 NaN     NaN   NaN
# ...         ...        ...        ...       ...       ...  ..     ...   ...
# 13005  2893.750  2869.7483 -2847.7483   85.0668  161.7025 NaN  0.0026   NaN
# 13006  2893.875  2869.8733 -2847.8733   85.2861  162.8190 NaN  0.0023   NaN
# 13007  2894.000  2869.9983 -2847.9983   85.4236  163.4554 NaN  0.0019   NaN
# 13008  2894.125  2870.1233 -2848.1233   85.5064  163.6382 NaN  0.0018   NaN
# 13009  2894.250  2870.2483 -2848.2483   85.5636  163.4386 NaN  0.0018   NaN
#
#          PHIF    RHOB   SW    VSH
# ...

# %%
# limites do reservatório
above_2600 = well['DEPTH'] < 2600
between_2600_2650 = (well['DEPTH'] >= 2600) & (well['DEPTH'] <= 2650)
below_2650 = well['DEPTH'] > 2650

# %%
fig = make_subplots(rows=1, cols=6, subplot_titles=('DT', 'DTS', 'RHOB', 'PHIF', 'VSH', 'SW'), horizontal_spacing=0.02)

fig.add_trace(go.Scatter(x=well['DT'][above_2600], y=well['DEPTH'][above_2600], name='DT', line=dict(color='#2E91E5')), row=1, col=1)
fig.add_trace(go.Scatter(x=well['DT'][between_2600_2650], y=well['DEPTH'][between_2600_2650], name='DT', line=dict(color='#AF0038')), row=1, col=1)
fig.add_trace(go.Scatter(x=well['DT'][below_2650], y=well['DEPTH'][below_2650], name='DT', line=dict(color='#2E91E5')), row=1, col=1)

# DTS
fig.add_trace(go.Scatter(x=well['DTS'][above_2600], y=well['DEPTH'][above_2600], name='DTS', line=dict(color='#2E91E5')), row=1, col=2)
fig.add_trace(go.Scatter(x=well['DTS'][between_2600_2650], y=well['DEPTH'][between_2600_2650], name='DTS', line=dict(color='#AF0038')), row=1, col=2)
fig.add_trace(go.Scatter(x=well['DTS'][below_2650], y=well['DEPTH'][below_2650], name='DTS', line=dict(color='#2E91E5')), row=1, col=2)

# RHOB
fig.add_trace(go.Scatter(x=well['RHOB'][above_2600], y=well['DEPTH'][above_2600], name='RHOB', line=dict(color='#2E91E5')), row=1, col=3)
fig.add_trace(go.Scatter(x=well['RHOB'][between_2600_2650], y=well['DEPTH'][between_2600_2650], name='RHOB', line=dict(color='#AF0038')), row=1, col=3)
fig.add_trace(go.Scatter(x=well['RHOB'][below_2650], y=well['DEPTH'][below_2650], name='RHOB', line=dict(color='#2E91E5')), row=1, col=3)

# PHIF
fig.add_trace(go.Scatter(x=well['PHIF'][above_2600], y=well['DEPTH'][above_2600], name='PHIF', line=dict(color='#2E91E5')), row=1, col=4)
fig.add_trace(go.Scatter(x=well['PHIF'][between_2600_2650], y=well['DEPTH'][between_2600_2650], name='PHIF', line=dict(color='#AF0038')), row=1, col=4)
fig.add_trace(go.Scatter(x=well['PHIF'][below_2650], y=well['DEPTH'][below_2650], name='PHIF', line=dict(color='#2E91E5')), row=1, col=4)

# VSH
fig.add_trace(go.Scatter(x=well['VSH'][above_2600], y=well['DEPTH'][above_2600], name='VSH', line=dict(color='#2E91E5')), row=1, col=5)
fig.add_trace(go.Scatter(x=well['VSH'][between_2600_2650], y=well['DEPTH'][between_2600_2650], name='VSH', line=dict(color='#AF0038')), row=1, col=5)
fig.add_trace(go.Scatter(x=well['VSH'][below_2650], y=well['DEPTH'][below_2650], name='VSH', line=dict(color='#2E91E5')), row=1, col=5)

# SW
fig.add_trace(go.Scatter(x=well['SW'][above_2600], y=well['DEPTH'][above_2600], name='SW', line=dict(color='#2E91E5')), row=1, col=6)
fig.add_trace(go.Scatter(x=well['SW'][between_2600_2650], y=well['DEPTH'][between_2600_2650], name='SW', line=dict(color='#AF0038')), row=1, col=6)
fig.add_trace(go.Scatter(x=well['SW'][below_2650], y=well['DEPTH'][below_2650], name='SW', line=dict(color='#2E91E5')), row=1, col=6)

# fig.add_trace(go.Scatter(x=well['DT'], y=well['DEPTH'], name='DT',
#                          line=dict(color='blue')), row=1, col=1)
# fig.add_trace(go.Scatter(x=well['DTS'], y=well['DEPTH'], name='RHOB',
#                          line=dict(color='blue')), row=1, col=2)
# fig.add_trace(go.Scatter(x=well['RHOB'], y=well['DEPTH'], name='GR',
#                          line=dict(color='blue')), row=1, col=3)
# fig.add_trace(go.Scatter(x=well['PHIF'], y=well['DEPTH'], name='VSH',
#                          line=dict(color='blue')), row=1, col=4)
# fig.add_trace(go.Scatter(x=well['VSH'], y=well['DEPTH'], name='PHIF',
#                          line=dict(color='blue')), row=1, col=5)
# fig.add_trace(go.Scatter(x=well['SW'], y=well['DEPTH'], name='SW',
#                          line=dict(color='blue')), row=1, col=6)

# fig.add_shape(type='line', x0=min(well['DT']), x1=max(well['DT']), xref='x1', y0=2600, y1=2600, yref='y1', line=dict(color='red', dash='dash'))
# fig.add_shape(type='line', x0=min(well['DT']), x1=max(well['DT']), xref='x1', y0=2700, y1=2700, yref='y1', line=dict(color='red', dash='dash'))

# Update xaxis properties
fig.update_xaxes(title_text='us/ft', row=1, col=1,
                 title_font=dict(size=22), tickfont=dict(size=20))
fig.update_xaxes(title_text='g/cm3', row=1, col=2,
                 title_font=dict(size=22), tickfont=dict(size=20))
fig.update_xaxes(title_text='API', row=1, col=3,
                 title_font=dict(size=22), tickfont=dict(size=20))
fig.update_xaxes(title_text='v/v', row=1, col=4,
                 title_font=dict(size=22), tickfont=dict(size=20))
fig.update_xaxes(title_text='v/v', row=1, col=5,
                 title_font=dict(size=22), tickfont=dict(size=20))
fig.update_xaxes(title_text='v/v', row=1, col=6,
                 title_font=dict(size=22), tickfont=dict(size=20))
fig.update_xaxes(title_text='v/v', row=1, col=7,
                 title_font=dict(size=22), tickfont=dict(size=20))

# Update yaxis properties
fig.update_yaxes(title_text="Depth (m)", autorange="reversed", row=1, col=1,
                 title_font=dict(size=22), tickfont=dict(size=20))
fig.update_yaxes(autorange="reversed", row=1, col=2, showticklabels=False,
                 title_font=dict(size=22), tickfont=dict(size=20))
fig.update_yaxes(autorange="reversed", row=1, col=3, showticklabels=False,
                 title_font=dict(size=22), tickfont=dict(size=20))
fig.update_yaxes(autorange="reversed", row=1, col=4, showticklabels=False,
                 title_font=dict(size=22), tickfont=dict(size=20))
fig.update_yaxes(autorange="reversed", row=1, col=5, showticklabels=False,
                 title_font=dict(size=22), tickfont=dict(size=20))
fig.update_yaxes(autorange="reversed", row=1, col=6, showticklabels=False,
                 title_font=dict(size=22), tickfont=dict(size=20))
fig.update_yaxes(autorange="reversed", row=1, col=7, showticklabels=False,
                 title_font=dict(size=22), tickfont=dict(size=20))

fig.update_layout(height=600, width=1400, showlegend=False,
                  title_text='<b>Well: 6608/10-B-2H<b>',
                  title_font=dict(size=24), title_x=0.5)

fig.update_annotations(font=dict(size=24))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
print(well.isnull())
# Out:
#        DEPTH    TVD  TVDSS    DT     GR  KLOGH  NPHI   PHIF  RHOB    SW    VSH
# 0      False  False  False  True  False   True  True   True  True  True   True
# 1      False  False  False  True  False   True  True   True  True  True   True
# 2      False  False  False  True  False   True  True   True  True  True   True
# 3      False  False  False  True  False   True  True   True  True  True   True
# 4      False  False  False  True  False   True  True   True  True  True   True
# ...      ...    ...    ...   ...    ...    ...   ...    ...   ...   ...    ...
# 27286  False  False  False  True   True  False  True  False  True  True  False
# 27287  False  False  False  True   True  False  True  False  True  True  False
# 27288  False  False  False  True   True  False  True  False  True  True  False
# 27289  False  False  False  True   True  False  True  False  True  True  False
# 27290  False  False  False  True   True  False  True  False  True  True  False
#
# ...

# %%
# Convertendo DT (us/ft) para VP (km/s)
well['VP'] = 1 / well['DT'] * 0.3048 * 10**6

# %%
# impedance
ip = []
ip = well['DT'] * well['RHOB']

# reflectivity
R = [np.zeros((n_z))]
for i in range(n_z - 1):
  R[i] = (ip[i + 1] - ip[i]) / (ip[i + 1] + ip[i])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     344             try:
# --> 345                 return self._range.index(new_key)
#     346             except ValueError as err:
#
# ValueError: 1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-80-e2d78aec3561> in <cell line: 7>()
#       6 R = []
#       7 for i in range(len(well['DEPTH']) - 1):
# ----> 8   R[i] = (ip[i + 1] - ip[i]) / (ip[i + 1] + ip[i])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1005
#    1006         elif key_is_scalar:
# -> 1007             return self._get_value(key)
#    1008
#    1009         if is_hashable(key):
#
# ...

# %%
fig = make_subplots(rows=1, cols=6, subplot_titles=('Velocity', 'Density', 'Impedance', 'PHIF', 'VSH', 'SW'), horizontal_spacing=0.02)

fig.add_trace(go.Scatter(x=well['VP'], y=well['DEPTH'], name='VP', line=dict(color='blue')), row=1, col=1)
fig.add_trace(go.Scatter(x=well['RHOB'], y=well['DEPTH'], name='RHOB', line=dict(color='blue')), row=1, col=2)
fig.add_trace(go.Scatter(x=ip, y=well['DEPTH'], name='IMPEDANCE', line=dict(color='blue')), row=1, col=3)

# Update xaxis properties
fig.update_xaxes(title_text='km/s', row=1, col=1, title_font=dict(size=22), tickfont=dict(size=20))
fig.update_xaxes(title_text='g/cm³', row=1, col=2, title_font=dict(size=22), tickfont=dict(size=20))
fig.update_xaxes(title_text='kg/(m²s)', row=1, col=3, title_font=dict(size=22), tickfont=dict(size=20))

# Update yaxis properties
fig.update_yaxes(title_text="Depth (m)", autorange="reversed", row=1, col=1,  title_font=dict(size=22), tickfont=dict(size=20))
fig.update_yaxes(autorange="reversed", row=1, col=2,  title_font=dict(size=22), tickfont=dict(size=20), showticklabels=False)
fig.update_yaxes(autorange="reversed", row=1, col=3,  title_font=dict(size=22), tickfont=dict(size=20), showticklabels=False)

fig.update_layout(height=600, width=1400, showlegend=False,
                  title_text='<b>Well tie<b>',
                  title_font=dict(size=24), title_x=0.5)

fig.update_annotations(font=dict(size=24))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
